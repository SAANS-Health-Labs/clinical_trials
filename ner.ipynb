# %%
# import sys
# !{sys.executable} -m pip install stanza

# %%
from datetime import datetime
date = datetime.today().strftime('%y%m%d')
print ('Last modified by Xiaoqing: ' + date)
# Out:
# Last modified by Xiaoqing: 211112

# %% [markdown]
# # Data source: 10 synthetic patients and 5 real clinical trials from google Drive

# %% [markdown]
# # Use environment: transformer

# %%
import stanza
import pandas as pd

# %%
# download and initialize a mimic pipeline with an i2b2 NER model
# stanza.download('en', package='mimic', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
# Out:
# 2021-11-12 16:15:53 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | mimic   |
# | pos       | mimic   |
# | lemma     | mimic   |
# | depparse  | mimic   |
# | ner       | i2b2    |
# =======================
#
# 2021-11-12 16:15:53 INFO: Use device: cpu
# 2021-11-12 16:15:53 INFO: Loading: tokenize
# 2021-11-12 16:15:53 INFO: Loading: pos
# 2021-11-12 16:15:53 INFO: Loading: lemma
# 2021-11-12 16:15:53 INFO: Loading: depparse
# 2021-11-12 16:15:53 INFO: Loading: ner
# 2021-11-12 16:15:54 INFO: Done loading processors!

# %% [markdown]
# # Named entity recognition: clinical trials

# %%
df = pd.read_csv('trials.csv')

# %%
# annotate clinical text; this is trial 1 from "ten_trials"
doc = nlp('Patient has history of a history of hypertension, and after antihypertensive treatment, systolic blood pressure ≥ 160 mmHg or diastolic blood pressure ≥ 100 mmHg ')
# print out all entities
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# hypertension	PROBLEM
# antihypertensive treatment	TREATMENT
# systolic blood pressure	TEST
# diastolic blood pressure	TEST

# %%
ent.text
# Out:
# 'diastolic blood pressure'

# %% [markdown]
# # One bullet point can have multiple problems, treatments, and tests

# %%
doc.entities
# Out:
# [{
#    "text": "hypertension",
#    "type": "PROBLEM",
#    "start_char": 36,
#    "end_char": 48
#  },
#  {
#    "text": "antihypertensive treatment",
#    "type": "TREATMENT",
#    "start_char": 60,
#    "end_char": 86
#  },
#  {
#    "text": "systolic blood pressure",
#    "type": "TEST",
#    "start_char": 88,
#    "end_char": 111
#  },
#  {
#    "text": "diastolic blood pressure",
#    "type": "TEST",
#    "start_char": 126,
#    "end_char": 150
#  }]

# %% [markdown]
# # Iterate through df sentences, record entities

# %%
df1 = pd.DataFrame(columns=['sentence_id','ent_text', 'ent_type']) # create empty df with column names only so we can append rows to it

# %%
for index, row in df.iterrows():
    doc = nlp(row['sentence'])
    for ent in doc.entities:
        df1 = df1.append({'sentence_id': row['sentence_id'], 'ent_text': ent.text, 'ent_type': ent.type}, ignore_index = True)

# %%
df1.head(10)
# Out:
#   sentence_id                           ent_text ent_type
# 0           1           type 2 diabetes mellitus  PROBLEM
# 1           3                              HbA1C     TEST
# 2           3                          screening     TEST
# 3           3                              HbA1C     TEST
# 4           4           type 1 diabetes mellitus  PROBLEM
# 5           5                       ketoacidosis  PROBLEM
# 6           6  severe unconscious hypoglycemosis  PROBLEM
# 7           7     acute and chronic pancreatitis  PROBLEM
# 8           7                  pancreatic injury  PROBLEM
# 9           7                       pancreatitis  PROBLEM

# %% [markdown]
# # Note: some sentences contain no detectible entities, like sentence_id = 2

# %%
df2 = pd.merge(df, df1, on='sentence_id',  how='left')
df2.head(15)
# Out:
#     trial_id sentence_id                                           sentence  \
# 0          1           1  Patients diagnosed with type 2 diabetes mellitus
# 1          1           2  Patients have treated with diet/exercise at le...
# 2          1           3  7.5% ≤HbA1C ≤11.0% at screening,7.0% ≤HbA1C ≤1...
# 3          1           3  7.5% ≤HbA1C ≤11.0% at screening,7.0% ≤HbA1C ≤1...
# 4          1           3  7.5% ≤HbA1C ≤11.0% at screening,7.0% ≤HbA1C ≤1...
# 5          1           4   Patient has history of type 1 diabetes mellitus
# 6          1           5               Patient has history of ketoacidosis
# 7          1           6  Patient has history of severe unconscious hypo...
# 8          1           7  Patient has history of acute and chronic pancr...
# 9          1           7  Patient has history of acute and chronic pancr...
# 10         1           7  Patient has history of acute and chronic pancr...
# 11         1           8  Patient has history of decompensated heart fai...
# 12         1           8  Patient has history of decompensated heart fai...
# 13         1           8  Patient has history of decompensated heart fai...
# 14         1           8  Patient has history of decompensated heart fai...
#
#     inclusion                           ent_text ent_type
# 0           1           type 2 diabetes mellitus  PROBLEM
# 1           1                                NaN      NaN
# 2           1                              HbA1C     TEST
# 3           1                          screening     TEST
# 4           1                              HbA1C     TEST
# 5           0           type 1 diabetes mellitus  PROBLEM
# 6           0                       ketoacidosis  PROBLEM
# 7           0  severe unconscious hypoglycemosis  PROBLEM
# 8           0     acute and chronic pancreatitis  PROBLEM
# 9           0                  pancreatic injury  PROBLEM
# 10          0                       pancreatitis  PROBLEM
# 11          0        decompensated heart failure  PROBLEM
# 12          0                    unstable angina  PROBLEM
# 13          0                             stroke  PROBLEM
# 14          0          transient ischemic attack  PROBLEM

# %%
df2.to_csv(('trials_ner_'+ date + '.csv'),index = False)

# %% [markdown]
# # To do: extract test minimum and maximum

# %% [markdown]
# # To do: how to compare sentences like "Patients have treated with diet/exercise at least 3 months"?

# %% [markdown]
# The only place we may find this type statement in a medical record will be physician ‘clinical notes’. If we label these entities as “other”, “we can potentially compare patient’s “other” entities with a trial’s “other” entities

# %% [markdown]
# # Named entity recognition: patient

# %%
df = pd.read_csv('patients_synthetic.csv')

# %%
# need to remove some artifacts like (disorder)
remove_words = ['disorder', 'finding', 'pls']
pat = r'\b(?:{})\b'.format('|'.join(remove_words))
df['sentence'] = df['sentence'].str.replace(pat, '')

df.tail()
# Out:
# /var/folders/n3/x7vymc8s2cj1p5yx96j08wlr0000gn/T/ipykernel_4971/657706421.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['sentence'] = df['sentence'].str.replace(pat, '')
#     patient_id  sentence_id                                           sentence
# 35           9           36                    hispanic 32 year old white Male
# 36          10           37                   Acetaminophen 325 MG Oral Tablet
# 37          10           38  111.0 mm[Hg] of Systolic 82.0 mm[Hg] of Diasto...
# 38          10           39  Acute viral pharyngitis () Viral sinusitis () ...
# 39          10           40                 nonhispanic 25 year old white Male

# %%
df1 = pd.DataFrame(columns=['sentence_id','ent_text', 'ent_type']) # create empty df with column names only so we can append rows to it

# %%
for index, row in df.iterrows():
    doc = nlp(row['sentence'])
    for ent in doc.entities:
        df1 = df1.append({'sentence_id': row['sentence_id'], 'ent_text': ent.text, 'ent_type': ent.type}, ignore_index = True)

# %%
df2 = pd.merge(df, df1, on='sentence_id',  how='left')
df2.head(15)
# Out:
#     patient_id sentence_id                                           sentence  \
# 0            1           1  Ibuprofen 200 MG Oral Tablet Naproxen sodium 2...
# 1            1           1  Ibuprofen 200 MG Oral Tablet Naproxen sodium 2...
# 2            1           1  Ibuprofen 200 MG Oral Tablet Naproxen sodium 2...
# 3            1           1  Ibuprofen 200 MG Oral Tablet Naproxen sodium 2...
# 4            1           1  Ibuprofen 200 MG Oral Tablet Naproxen sodium 2...
# 5            1           1  Ibuprofen 200 MG Oral Tablet Naproxen sodium 2...
# 6            1           2  118.0 mm[Hg] of Systolic 74.0 mm[Hg] of Diasto...
# 7            1           2  118.0 mm[Hg] of Systolic 74.0 mm[Hg] of Diasto...
# 8            1           2  118.0 mm[Hg] of Systolic 74.0 mm[Hg] of Diasto...
# 9            1           2  118.0 mm[Hg] of Systolic 74.0 mm[Hg] of Diasto...
# 10           1           2  118.0 mm[Hg] of Systolic 74.0 mm[Hg] of Diasto...
# 11           1           2  118.0 mm[Hg] of Systolic 74.0 mm[Hg] of Diasto...
# 12           1           2  118.0 mm[Hg] of Systolic 74.0 mm[Hg] of Diasto...
# 13           1           3  Diabetes Anemia () Hypertriglyceridemia () Met...
# 14           1           3  Diabetes Anemia () Hypertriglyceridemia () Met...
#
#                                       ent_text   ent_type
# 0                                    Ibuprofen  TREATMENT
# 1                              Naproxen sodium  TREATMENT
# 2                                Acetaminophen  TREATMENT
# 3                Dextromethorphan Hydrobromide  TREATMENT
# 4                         doxylamine succinate  TREATMENT
# 5                      Metformin hydrochloride  TREATMENT
# 6                                           Hg       TEST
# 7                                     Systolic       TEST
# 8                                           Hg       TEST
# 9                                    Diastolic       TEST
# 10                                         BMI       TEST
# 11                                        HA1c       TEST
# 12                              total in blood       TEST
# 13                             Diabetes Anemia    PROBLEM
# 14  Hypertriglyceridemia () Metabolic syndrome    PROBLEM

# %%
df2.to_csv(('patients_ner_'+ date + '.csv'),index = False)

# %% [markdown]
# # summary: 10 patients produced 55 diagnosis. 5 clinical trials produced 65 diagnoses.

# %% [markdown]
# # unused notes

# %%
# annotate clinical text; this is patient 1 from "Patients"
doc = nlp('Ibuprofen 200 MG Oral Tablet Naproxen sodium 220 MG Oral Tablet Acetaminophen 21.7 MG/ML / Dextromethorphan Hydrobromide 1 MG/ML / doxylamine succinate 0.417 MG/ML Oral Solution 24 HR Metformin hydrochloride 500 MG Extended Release Oral Tablet. 118.0 mm[Hg] of Systolic 74.0 mm[Hg] of Diastolic 30.1 BMI 7.5 HA1c total in blood. Diabetes Anemia Hypertriglyceridemia Metabolic syndrome X Whiplash injury to neck Viral sinusitis Facial laceration Acute bronchitis')
# print out all entities
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# Ibuprofen	TREATMENT
# Naproxen sodium	TREATMENT
# Acetaminophen	TREATMENT
# Dextromethorphan Hydrobromide	TREATMENT
# doxylamine succinate	TREATMENT
# Metformin hydrochloride	TREATMENT
# Hg	TEST
# Systolic	TEST
# Hg	TEST
# Diastolic	TEST
# BMI	TEST
# HA1c	TEST
# total in blood	TEST
# Diabetes Anemia	PROBLEM
# Hypertriglyceridemia	PROBLEM
# Metabolic syndrome	PROBLEM
# Whiplash injury to neck	PROBLEM
# Viral sinusitis	PROBLEM
# Facial laceration	PROBLEM
# Acute bronchitis	PROBLEM

# %%
# get the relationships
doc.sentences[0].print_dependencies
# Out:
# <bound method Sentence.print_dependencies of [
#   {
#     "id": 1,
#     "text": "Ibuprofen",
#     "lemma": "Ibuprofen",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 9,
#     "ner": "S-TREATMENT"
#   },
#   {
#     "id": 2,
#     "text": "200",
#     "lemma": "200",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 3,
#     "deprel": "nummod",
#     "start_char": 10,
#     "end_char": 13,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": "MG",
#     "lemma": "mg",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 14,
#     "end_char": 16,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "Oral",
#     "lemma": "Oral",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "head": 5,
#     "deprel": "compound",
#     "start_char": 17,
#     "end_char": 21,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": "Tablet",
#     "lemma": "Tablet",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 22,
#     "end_char": 28,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "Naproxen",
#     "lemma": "Naproxen",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "head": 7,
#     "deprel": "compound",
#     "start_char": 29,
#     "end_char": 37,
#     "ner": "B-TREATMENT"
#   },
#   {
#     "id": 7,
#     "text": "sodium",
#     "lemma": "sodium",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 38,
#     "end_char": 44,
#     "ner": "E-TREATMENT"
#   },
#   {
#     "id": 8,
#     "text": "220",
#     "lemma": "220",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 9,
#     "deprel": "nummod",
#     "start_char": 45,
#     "end_char": 48,
#     "ner": "O"
#   },
#   {
#     "id": 9,
#     "text": "MG",
#     "lemma": "mg",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 11,
#     "deprel": "compound",
#     "start_char": 49,
#     "end_char": 51,
#     "ner": "O"
#   },
#   {
#     "id": 10,
#     "text": "Oral",
#     "lemma": "Oral",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "head": 11,
#     "deprel": "compound",
#     "start_char": 52,
#     "end_char": 56,
#     "ner": "O"
#   },
#   {
#     "id": 11,
#     "text": "Tablet",
#     "lemma": "tablet",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 57,
#     "end_char": 63,
#     "ner": "O"
#   },
#   {
#     "id": 12,
#     "text": "Acetaminophen",
#     "lemma": "acetaminophen",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 64,
#     "end_char": 77,
#     "ner": "S-TREATMENT"
#   },
#   {
#     "id": 13,
#     "text": "21.7",
#     "lemma": "21.7",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 14,
#     "deprel": "nummod",
#     "start_char": 78,
#     "end_char": 82,
#     "ner": "O"
#   },
#   {
#     "id": 14,
#     "text": "MG/ML",
#     "lemma": "mg/ml",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 83,
#     "end_char": 88,
#     "ner": "O"
#   },
#   {
#     "id": 15,
#     "text": "/",
#     "lemma": "/",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 16,
#     "deprel": "cc",
#     "start_char": 89,
#     "end_char": 90,
#     "ner": "O"
#   },
#   {
#     "id": 16,
#     "text": "Dextromethorphan",
#     "lemma": "dextromethorphan",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 14,
#     "deprel": "conj",
#     "start_char": 91,
#     "end_char": 107,
#     "ner": "B-TREATMENT"
#   },
#   {
#     "id": 17,
#     "text": "Hydrobromide",
#     "lemma": "Hydrobromide",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 108,
#     "end_char": 120,
#     "ner": "E-TREATMENT"
#   },
#   {
#     "id": 18,
#     "text": "1",
#     "lemma": "1",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 19,
#     "deprel": "nummod",
#     "start_char": 121,
#     "end_char": 122,
#     "ner": "O"
#   },
#   {
#     "id": 19,
#     "text": "MG/ML",
#     "lemma": "mg/ml",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 123,
#     "end_char": 128,
#     "ner": "O"
#   },
#   {
#     "id": 20,
#     "text": "/",
#     "lemma": "/",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 21,
#     "deprel": "cc",
#     "start_char": 129,
#     "end_char": 130,
#     "ner": "O"
#   },
#   {
#     "id": 21,
#     "text": "doxylamine",
#     "lemma": "doxylamine",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 19,
#     "deprel": "compound",
#     "start_char": 131,
#     "end_char": 141,
#     "ner": "B-TREATMENT"
#   },
#   {
#     "id": 22,
#     "text": "succinate",
#     "lemma": "succinate",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 142,
#     "end_char": 151,
#     "ner": "E-TREATMENT"
#   },
#   {
#     "id": 23,
#     "text": "0.417",
#     "lemma": "0.417",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 24,
#     "deprel": "nummod",
#     "start_char": 152,
#     "end_char": 157,
#     "ner": "O"
#   },
#   {
#     "id": 24,
#     "text": "MG",
#     "lemma": "mg",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 158,
#     "end_char": 160,
#     "ner": "O"
#   },
#   {
#     "id": 25,
#     "text": "/",
#     "lemma": "/",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 26,
#     "deprel": "cc",
#     "start_char": 160,
#     "end_char": 161,
#     "ner": "O"
#   },
#   {
#     "id": 26,
#     "text": "ML",
#     "lemma": "ml",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 24,
#     "deprel": "conj",
#     "start_char": 161,
#     "end_char": 163,
#     "ner": "O"
#   },
#   {
#     "id": 27,
#     "text": "Oral",
#     "lemma": "oral",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 28,
#     "deprel": "compound",
#     "start_char": 164,
#     "end_char": 168,
#     "ner": "O"
#   },
#   {
#     "id": 28,
#     "text": "Solution",
#     "lemma": "solution",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 169,
#     "end_char": 177,
#     "ner": "O"
#   },
#   {
#     "id": 29,
#     "text": "24",
#     "lemma": "24",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 31,
#     "deprel": "nummod",
#     "start_char": 178,
#     "end_char": 180,
#     "ner": "O"
#   },
#   {
#     "id": 30,
#     "text": "HR",
#     "lemma": "hr",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 31,
#     "deprel": "compound",
#     "start_char": 181,
#     "end_char": 183,
#     "ner": "O"
#   },
#   {
#     "id": 31,
#     "text": "Metformin",
#     "lemma": "metformin",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 184,
#     "end_char": 193,
#     "ner": "B-TREATMENT"
#   },
#   {
#     "id": 32,
#     "text": "hydrochloride",
#     "lemma": "hydrochloride",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 194,
#     "end_char": 207,
#     "ner": "E-TREATMENT"
#   },
#   {
#     "id": 33,
#     "text": "500",
#     "lemma": "500",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 34,
#     "deprel": "nummod",
#     "start_char": 208,
#     "end_char": 211,
#     "ner": "O"
#   },
#   {
#     "id": 34,
#     "text": "MG",
#     "lemma": "mg",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 212,
#     "end_char": 214,
#     "ner": "O"
#   },
#   {
#     "id": 35,
#     "text": "Extended",
#     "lemma": "extend",
#     "upos": "VERB",
#     "xpos": "VBN",
#     "head": 36,
#     "deprel": "amod",
#     "start_char": 215,
#     "end_char": 223,
#     "ner": "O"
#   },
#   {
#     "id": 36,
#     "text": "Release",
#     "lemma": "release",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 224,
#     "end_char": 231,
#     "ner": "O"
#   },
#   {
#     "id": 37,
#     "text": "Oral",
#     "lemma": "oral",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 232,
#     "end_char": 236,
#     "ner": "O"
#   },
#   {
#     "id": 38,
#     "text": "Tablet.",
#     "lemma": "tablet.",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 237,
#     "end_char": 244,
#     "ner": "O"
#   },
#   {
#     "id": 39,
#     "text": "118.0",
#     "lemma": "118.0",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 40,
#     "deprel": "nummod",
#     "start_char": 245,
#     "end_char": 250,
#     "ner": "O"
#   },
#   {
#     "id": 40,
#     "text": "mm",
#     "lemma": "mm",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 251,
#     "end_char": 253,
#     "ner": "O"
#   },
#   {
#     "id": 41,
#     "text": "[",
#     "lemma": "[",
#     "upos": "PUNCT",
#     "xpos": "-LRB-",
#     "head": 42,
#     "deprel": "punct",
#     "start_char": 253,
#     "end_char": 254,
#     "ner": "O"
#   },
#   {
#     "id": 42,
#     "text": "Hg",
#     "lemma": "hg",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 254,
#     "end_char": 256,
#     "ner": "S-TEST"
#   },
#   {
#     "id": 43,
#     "text": "]",
#     "lemma": "]",
#     "upos": "PUNCT",
#     "xpos": "-RRB-",
#     "head": 42,
#     "deprel": "punct",
#     "start_char": 256,
#     "end_char": 257,
#     "ner": "O"
#   },
#   {
#     "id": 44,
#     "text": "of",
#     "lemma": "of",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 47,
#     "deprel": "case",
#     "start_char": 258,
#     "end_char": 260,
#     "ner": "O"
#   },
#   {
#     "id": 45,
#     "text": "Systolic",
#     "lemma": "systolic",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 47,
#     "deprel": "compound",
#     "start_char": 261,
#     "end_char": 269,
#     "ner": "S-TEST"
#   },
#   {
#     "id": 46,
#     "text": "74.0",
#     "lemma": "74.0",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 47,
#     "deprel": "nummod",
#     "start_char": 270,
#     "end_char": 274,
#     "ner": "O"
#   },
#   {
#     "id": 47,
#     "text": "mm",
#     "lemma": "mm",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 275,
#     "end_char": 277,
#     "ner": "O"
#   },
#   {
#     "id": 48,
#     "text": "[",
#     "lemma": "[",
#     "upos": "PUNCT",
#     "xpos": "-LRB-",
#     "head": 49,
#     "deprel": "punct",
#     "start_char": 277,
#     "end_char": 278,
#     "ner": "O"
#   },
#   {
#     "id": 49,
#     "text": "Hg",
#     "lemma": "hg",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 47,
#     "deprel": "appos",
#     "start_char": 278,
#     "end_char": 280,
#     "ner": "S-TEST"
#   },
#   {
#     "id": 50,
#     "text": "]",
#     "lemma": "]",
#     "upos": "PUNCT",
#     "xpos": "-RRB-",
#     "head": 49,
#     "deprel": "punct",
#     "start_char": 280,
#     "end_char": 281,
#     "ner": "O"
#   },
#   {
#     "id": 51,
#     "text": "of",
#     "lemma": "of",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 52,
#     "deprel": "case",
#     "start_char": 282,
#     "end_char": 284,
#     "ner": "O"
#   },
#   {
#     "id": 52,
#     "text": "Diastolic",
#     "lemma": "diastolic",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 54,
#     "deprel": "compound",
#     "start_char": 285,
#     "end_char": 294,
#     "ner": "S-TEST"
#   },
#   {
#     "id": 53,
#     "text": "30.1",
#     "lemma": "30.1",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 54,
#     "deprel": "nummod",
#     "start_char": 295,
#     "end_char": 299,
#     "ner": "O"
#   },
#   {
#     "id": 54,
#     "text": "BMI",
#     "lemma": "bmi",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 57,
#     "deprel": "compound",
#     "start_char": 300,
#     "end_char": 303,
#     "ner": "S-TEST"
#   },
#   {
#     "id": 55,
#     "text": "7.5",
#     "lemma": "7.5",
#     "upos": "NUM",
#     "xpos": "CD",
#     "head": 54,
#     "deprel": "nummod",
#     "start_char": 304,
#     "end_char": 307,
#     "ner": "O"
#   },
#   {
#     "id": 56,
#     "text": "HA1c",
#     "lemma": "ha1c",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 57,
#     "deprel": "compound",
#     "start_char": 308,
#     "end_char": 312,
#     "ner": "S-TEST"
#   },
#   {
#     "id": 57,
#     "text": "total",
#     "lemma": "total",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 1,
#     "deprel": "list",
#     "start_char": 313,
#     "end_char": 318,
#     "ner": "B-TEST"
#   },
#   {
#     "id": 58,
#     "text": "in",
#     "lemma": "in",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 59,
#     "deprel": "case",
#     "start_char": 319,
#     "end_char": 321,
#     "ner": "I-TEST"
#   },
#   {
#     "id": 59,
#     "text": "blood",
#     "lemma": "blood",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "head": 57,
#     "deprel": "nmod",
#     "start_char": 322,
#     "end_char": 327,
#     "ner": "E-TEST"
#   },
#   {
#     "id": 60,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 1,
#     "deprel": "punct",
#     "start_char": 327,
#     "end_char": 328,
#     "ner": "O"
#   }
# ]>
